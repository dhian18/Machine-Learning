# %% [markdown]
# #**SUPERMARKET SALES PREDICTION**
#
# Nama : Dhian
#
#
# Nim : H071201073

# %% [markdown]
# ![](https://www.growthmanifesto.com/wp-content/uploads/2018/08/supermarket-sales.jpg)

# %% [markdown]
# # IMPORT LIBRARI

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # READ DATA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/SEMESTER 5/Meachine Learning/supermarket_sales - Sheet1.csv")

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.value_counts()
# Out:
# Invoice ID   Branch  City       Customer type  Gender  Product line         Unit price  Quantity  Tax 5%   Total     Date       Time   Payment      cogs    gross margin percentage  gross income  Rating
# 101-17-6199  A       Yangon     Normal         Male    Food and beverages   45.79       7         16.0265  336.5565  3/13/2019  19:44  Credit card  320.53  4.761905                 16.0265       7.0       1
# 641-62-7288  B       Mandalay   Normal         Male    Home and lifestyle   99.92       6         29.9760  629.4960  3/24/2019  13:33  Ewallet      599.52  4.761905                 29.9760       7.1       1
# 633-91-1052  A       Yangon     Normal         Female  Home and lifestyle   12.03       2         1.2030   25.2630   1/27/2019  15:51  Cash         24.06   4.761905                 1.2030        5.1       1
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# **Checking Null Value**

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Invoice ID                 False
# Branch                     False
# City                       False
# Customer type              False
# Gender                     False
# Product line               False
# Unit price                 False
# Quantity                   False
# Tax 5%                     False
# Total                      False
# Date                       False
# Time                       False
# Payment                    False
# cogs                       False
# gross margin percentage    False
# gross income               False
# Rating                     False
# dtype: bool

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# **HISTOGRAM**
#
# **Histogram pada dasarnya digunakan untuk mewakili data yang disediakan dalam bentuk beberapa grup. Ini adalah metode yang akurat untuk representasi grafis dari distribusi data numerik. Ini adalah jenis plot batang di mana sumbu X mewakili rentang bin sementara sumbu Y memberikan informasi tentang frekuensi.**

# %%
data.hist(figsize=(20,14))
plt.show()

# %%
data.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...

# %% [markdown]
# **HEATMAP**
#
# **HEATMAP adalah representasi grafis dari data yang menggunakan sistem kode warna untuk mewakili nilai yang berbeda. HEATMAP digunakan dalam berbagai bentuk analitik, tetapi paling sering digunakan untuk menunjukkan perilaku pengguna pada halaman web atau template halaman web tertentu.**

# %%
plt.figure(figsize = (12,10))

sns.heatmap(data.corr(), annot =True)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# **BOXPLOT**
#
# **Boxplot adalah cara standar untuk menampilkan distribusi data berdasarkan ringkasan lima angka ("minimum", kuartil pertama (Q1), median, kuartil ketiga (Q3), dan "maksimum"). ... Itu juga dapat memberi tahu Anda jika data Anda simetris, seberapa erat data Anda dikelompokkan, dan jika dan bagaimana data Anda miring.**

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='Unit price',data=data)
plt.subplot(2,3,2)
sns.boxplot(x='Quantity',data=data)
plt.subplot(2,3,3)
sns.boxplot(x='Total',data=data)
plt.subplot(2,3,4)
sns.boxplot(x='cogs',data=data)
plt.subplot(2,3,5)
sns.boxplot(x='Rating',data=data)
plt.subplot(2,3,6)
sns.boxplot(x='gross income',data=data)

# %% [markdown]
# **PAIRPLOT**
#
# **Plot pasangan memplot hubungan berpasangan dalam kumpulan data. Fungsi pairplot membuat kisi Sumbu sedemikian rupa sehingga setiap variabel dalam data akan dibagi dalam sumbu y di satu baris dan di sumbu x di satu kolom.**

# %%
sns.pairplot(data=data)

# %% [markdown]
# **REGPLOT**
#
# **Metode ini digunakan untuk memplot data dan fit model regresi linier. ... Jika string, ini harus sesuai dengan nama kolom di "data". Saat objek panda digunakan, sumbu akan diberi label dengan nama seri. data: Ini adalah kerangka data di mana setiap kolom adalah variabel dan setiap baris adalah observasi.**

# %%
sns.regplot(x='Rating', y= 'gross income', data=data)

# %% [markdown]
# **SCATTER PLOT**
#
# **Plot sebar (alias bagan sebar, grafik sebar) menggunakan titik untuk mewakili nilai untuk dua variabel numerik yang berbeda. Posisi setiap titik pada sumbu horizontal dan vertikal menunjukkan nilai untuk titik data individual. Plot pencar digunakan untuk mengamati hubungan antar variabel.**

# %%
sns.scatterplot(x='Rating', y= 'cogs', data=data)

# %% [markdown]
# **JOINTPLOT**
#
# **Seaborn's jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins. This plot is a convenience class that wraps JointGrid.**

# %%
sns.jointplot(x='Rating', y= 'Total', data=data)

# %% [markdown]
# **CATPLOT**
#
# **Catplot adalah tambahan yang relatif baru untuk Seaborn yang menyederhanakan pembuatan plot yang melibatkan variabel kategorikal. Dalam versi Seaborn v0. 9.0 yang keluar pada Juli 2018, mengubah plot faktor lama menjadi catplot agar lebih konsisten dengan terminologi di panda dan di seaborn.**

# %%
sns.catplot(x='Rating', y= 'cogs', data=data)

# %% [markdown]
# **LMPLOT**
#
# **Lineplot (lmplot) adalah salah satu plot paling dasar. Ini menunjukkan garis pada bidang 2 dimensi. Anda dapat memplotnya dengan seaborn atau matlotlib tergantung pada preferensi Anda. Contoh di bawah menggunakan seaborn untuk membuat plot, tetapi matplotlib untuk ditampilkan.**

# %%
sns.lmplot(x='Rating', y= 'cogs', data=data)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# **KDE PLOT (DENSITY PLOT)**
#
# **KDE Plot dijelaskan sebagai Perkiraan Kepadatan Kernel digunakan untuk memvisualisasikan Kepadatan Probabilitas dari variabel kontinu. Ini menggambarkan kepadatan probabilitas pada nilai yang berbeda dalam variabel kontinu. Kami juga dapat memplot satu grafik untuk banyak sampel yang membantu dalam visualisasi data yang lebih efisien.**

# %%
plt.style.use("default")

sns.kdeplot(x='Rating', y= 'Unit price', data=data)

# %% [markdown]
# **LINEPLOT**
#
# **Plot Garis dapat didefinisikan sebagai grafik yang menampilkan data sebagai titik atau tanda centang di atas garis angka, yang menunjukkan frekuensi setiap nilai.**

# %%
sns.lineplot(x='Rating', y= 'Unit price', data=data)

# %% [markdown]
# **BARPLOT**
#
# **Barplot (atau barchart) adalah salah satu jenis grafik yang paling umum. Ini menunjukkan hubungan antara numerik dan variabel kategori. Setiap entitas dari variabel kategori direpresentasikan sebagai batang. Ukuran bilah mewakili nilai numeriknya.**

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Unit price", data=data[170:180])
plt.title("Rating vs Unit Price",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Unit Price")
plt.show()

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Gender", data=data[170:180])
plt.title("Rating vs Gender",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Gender")
plt.show()

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Quantity", data=data[170:180])
plt.title("Rating vs Quantity",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Quantity")
plt.show()

# %%
#lets find the categorialfeatures
list_1=list(data.columns)

# %%
list_cate=[]
for i in list_1:
    if data[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#      Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0           814       0     2              0       0             3
# 1           142       2     1              1       0             0
# 2           653       0     2              1       1             4
# 3            18       0     2              0       1             3
# 4           339       0     2              1       1             5
# ..          ...     ...   ...            ...     ...           ...
# 995         153       2     1              1       1             3
# 996         250       1     0              1       0             4
# 997         767       0     2              0       1             2
# 998         308       0     2              1       1             4
# 999         935       0     2              0       0             1
#
#      Unit price  Quantity   Tax 5%      Total  Date  Time  Payment    cogs  \
# 0         74.69         7  26.1415   548.9715    26   146        2  522.83
# ...

# %%
y=data['Gender']
x=data.drop('Gender',axis=1)

# %% [markdown]
# # TRAINING AND TESTING DATA

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 800
# 200
# 800
# 200

# %% [markdown]
# # MODELS
#
# **1. KNeighborsClassifier**
#
# **Secara default, KNeighboursClassifier mencari 5 tetangga terdekat. Kita harus secara eksplisit memberi tahu pengklasifikasi untuk menggunakan jarak Euclidean untuk menentukan kedekatan antara titik-titik yang berdekatan.**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.47      0.49      0.48       100
#            1       0.47      0.45      0.46       100
#
#     accuracy                           0.47       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.47      0.47      0.47       200
#
# Confusion Matrix:
#  [[49 51]
#  [55 45]]
# Training Score:
#  64.75

# %% [markdown]
# **2. SVC**
#
# **Dalam pembelajaran mesin, mesin vektor pendukung (SVM, juga jaringan vektor pendukung) adalah model pembelajaran terawasi dengan algoritme pembelajaran terkait yang menganalisis data untuk klasifikasi dan analisis regresi.**

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",svc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.45      0.49      0.47       100
#            1       0.44      0.40      0.42       100
#
#     accuracy                           0.45       200
#    macro avg       0.44      0.45      0.44       200
# weighted avg       0.44      0.45      0.44       200
#
# Confusion Matrix:
#  [[49 51]
#  [60 40]]
# Training Score:
#  55.50000000000001

# %% [markdown]
# **3. DECISION TREE CLASSIFIER**
#
# **DECISION TREE CLASSIFIER menggunakan beberapa algoritma untuk memutuskan untuk membagi sebuah node menjadi dua atau lebih sub-node. Penciptaan sub-node meningkatkan homogenitas sub-node yang dihasilkan. ... DECISION TREE membagi node pada semua variabel yang tersedia dan kemudian memilih pemisahan yang menghasilkan sub-node yang paling homogen.**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.52      0.79      0.63       100
#            1       0.56      0.27      0.36       100
#
#     accuracy                           0.53       200
#    macro avg       0.54      0.53      0.50       200
# weighted avg       0.54      0.53      0.50       200
#
# Confusion Matrix:
#  [[79 21]
#  [73 27]]
# Training Score:
#  63.87500000000001

# %% [markdown]
# **4. Random Forest Classifier**
#
# **Random Forest Classifier. Random Forest Classifier adalah estimator meta yang cocok dengan sejumlah pengklasifikasi pohon keputusan pada berbagai sub-sampel dari kumpulan data dan menggunakan rata-rata untuk meningkatkan akurasi prediksi dan kontrol over-fitting.**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.49      0.49      0.49       100
#            1       0.48      0.48      0.48       100
#
#     accuracy                           0.48       200
#    macro avg       0.48      0.48      0.48       200
# weighted avg       0.48      0.48      0.48       200
#
# Confusion Matrix:
#  [[49 51]
#  [52 48]]
# Training Score:
#  100.0

# %% [markdown]
# **CONCLUSION :**
#
# **AKURASI MODEL YANG BERBEDA:**
#
# **KNeighbors Classifier= 64.75 %**
#
# **SVC= 55.50 %**
#
# **Decision Tree Classifier= 64 %**
#
# **Random Forest Classifier= 100 %**
#
#
# **Akurasi yang baik sekitar 100% dengan menggunakan Random Forest Classifier yang cukup baik untuk dataset yang diberikan.**
#
# **Akurasi model lain dapat ditingkatkan lebih lanjut dengan HyperTuning.**
